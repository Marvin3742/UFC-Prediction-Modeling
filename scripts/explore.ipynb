# %%
import pandas as pd

# %%
file = "../cleaned/cleaned_fighters.csv"
df = pd.read_csv(file)
df.head()
duplicates = list(df[df['fighter_name'].duplicated()]['fighter_name'])
duplicates
# Out:
# ['Mike Davis',
#  'Joey Gomez',
#  'Tony Johnson',
#  'Michael McDonald',
#  'Bruno Silva',
#  'Jean Silva',
#  'Victor Valenzuela']

# %%
id = df[df['fighter_name'] == 'Jean Silva'].index
print(f'id is : {id}')
# Out:
# id is : Index([3682, 3707], dtype='int64')

# %%
df = pd.read_csv('../cleaned/fighter_fights.csv')
df['fighter_id'] = df['fighter_id'] + 1
df['fight_id'] = df['fight_id'] + 1
df.to_csv('fighter_fights.csv', index=False)
